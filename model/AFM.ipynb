# %%
import os
os.chdir("/content/drive/MyDrive/Colab Notebooks/推荐系统/推荐系统算法复现/ml-100k")
import numpy as np
import pandas as pd
from torch.utils.data import DataLoader
import torch
from torch import nn
from torch.nn import Parameter,init
from sklearn.metrics import precision_score, recall_score, accuracy_score

# %%
# 导入user_df和item_df
user_df = pd.read_csv("./user_df.csv")
user_df = user_df.iloc[:,1:]
user_df.index += 1
item_df = pd.read_csv("./item_df.csv")
item_df = item_df.iloc[:,1:]
item_df.index += 1

# %%
user_df.head()
# Out:
#    age  gender  occupation
# 1    2       9          29
# 2    5       8          23
# 3    2       9          30
# 4    2       9          29
# 5    3       8          23

# %%
item_df.head()
# Out:
#    unknown  Action  Adventure  Animation  Children's  Comedy  Crime  \
# 1       30      31         32         34          35      36     36
# 2       30      32         33         33          34      35     36
# 3       30      31         32         33          34      35     36
# 4       30      32         32         33          34      36     36
# 5       30      31         32         33          34      35     37
#
#    Documentary  Drama  Fantasy  Film-Noir  Horror  Musical  Mystery  Romance  \
# 1           37     38       39         40      41       42       43       44
# 2           37     38       39         40      41       42       43       44
# 3           37     38       39         40      41       42       43       44
# 4           37     39       39         40      41       42       43       44
# 5           37     39       39         40      41       42       43       44
#
#    Sci-Fi  Thriller  War  Western
# 1      45        46   47       48
# 2      45        47   47       48
# 3      45        47   47       48
# 4      45        46   47       48
# 5      45        47   47       48

# %%
# 导入user-item交互矩阵
data = pd.read_csv("./user_item2.csv")
data.drop(data.columns[0], axis=1, inplace=True)
data.head()
# Out:
#    user_id  item_id  rating
# 0        1       55       1
# 1        1      203       1
# 2        1      183       1
# 3        1      150       1
# 4        1       68       1

# %%
import numpy as np

# 设置随机数生成器的种子
np.random.seed(0)
# 创建一个1到10000的数组
arr = np.arange(data.shape[0])
# 原地随机排列数组
np.random.shuffle(arr)
# 选择百分之多少的数据作为训练集
train_test_ratio = 0.9
# 打乱后的数组的前百分之train_test_ratio(i.e.90%)作为训练集对应的index
train_index = arr[:int(len(arr)*train_test_ratio)]
# 打乱后的数组的后百分之(1-train_test_ratio)(i.e.10%)作为测试集对应的index
test_index = arr[int(len(arr)*train_test_ratio):]
# 获取训练集和测试集
train_set = data.iloc[train_index,:]
test_set = data.iloc[test_index, :]

# 将训练集和测试集的每一行都变成一个元组，方便后续处理
train_set = [tuple(row) for row in train_set.itertuples(index=False, name=None)]
test_set = [tuple(row) for row in test_set.itertuples(index=False, name=None)]

# %%
from PIL import Image
os.chdir("/content/drive/MyDrive/Colab Notebooks/推荐系统/推荐系统算法复现/图片")
image_path = "./AFM.png"
image = Image.open(image_path)
new_size = (700, 500)
resized_image = image.resize(new_size)
resized_image
# Out:
# <PIL.Image.Image image mode=RGBA size=700x500>

# %%
class AFM(nn.Module):
    def __init__(self, features_value_count, hidden_dim, t, user_df, item_df):
        super(AFM, self).__init__()
        # 记录好用户和物品的特征索引
        self.user_df = user_df
        self.item_df = item_df

        # 嵌入层
        self.embeddings = nn.Embedding(features_value_count, hidden_dim)

        # 注意力层
        self.attn_w = init.xavier_uniform_(nn.Parameter(torch.empty(t, hidden_dim)))
        #self.attn_b = init.xavier_uniform_(nn.Parameter(torch.empty(t)))
        self.h = init.xavier_uniform_(nn.Parameter(torch.empty(t,hidden_dim)))

    #把用户和物品的特征合并起来
    def concat_user_item_vec( self, u, i ):
      # users的shape为(batch_size, users表格的特征个数)
      users = torch.LongTensor( self.user_df.loc[u].values )
      # items的shape为(batch_size, items表格的特征个数)
      items = torch.LongTensor( self.item_df.loc[i].values )
      # concat_vec的shape为(batch_size, users表格的特征个数+items表格的特征个数)
      concat_vec = torch.cat( [ users, items ], dim = 1 )
      return concat_vec

    def attention(self, x):
      # 输入x的shape为(batch_size, hidden_dim)
      # out的shape为(feature_num, batch_size)
      #out = self.h.T @ torch.relu(self.attn_w @ x.T + self.attn_b)
      out = self.h.T @ torch.relu(self.attn_w @ x.T)
      # out的shape为(batch_size, feature_num)
      out = out.T
      # attn_out的shape为(batch_size, feature_num)
      attn_out = torch.softmax(out, axis = 1)
      return attn_out

    def forward(self, u, i):
        # 得到用户与物品组合起来后的特征索引
        # concat_vec_index的shape为(batch_size, users表格的特征个数+items表格的特征个数(or num_features))
        concat_vec_index = self.concat_user_item_vec( u, i )
        # 通过Embedding层，得到concat_vec_index中每个值对应的隐向量
        # embeddings的shape为(batch_size, num_features, hidden_dim )
        embeddings = self.embeddings( concat_vec_index )
        # sum_squared的shape为(batch_size, hidden_dim)
        sum_squared = torch.sum(embeddings, dim=1) ** 2
        # squared_sum的shape为(batch_size, hidden_dim)
        squared_sum = torch.sum(embeddings ** 2, dim=1)
        # bilinear的shape为(batch_size, hidden_dim)
        bilinear = sum_squared - squared_sum

        # attention_weight的shape为(batch_size, hidden_dim)
        attention_weight = self.attention(bilinear)
        # out的shape为(batch_size)
        out = (attention_weight * bilinear).sum(axis = 1)
        out = torch.sigmoid(out)
        return out

# %%
# 创建模型实例
features_value_count = item_df.values.max() + 1
hidden_dim = 32
t = 16
model = AFM(features_value_count, hidden_dim, t, user_df, item_df)

# %%
def evaluation(y_pred, y_true):
  p = precision_score(y_true, y_pred)
  r = recall_score(y_true, y_pred)
  acc = accuracy_score(y_true,y_pred)
  return p,r,acc

# %%
# 实例化损失函数和优化器
from torch.utils.data import DataLoader
from sklearn.metrics import precision_score,recall_score,accuracy_score
import torch.optim as optim
optimizer = optim.Adam(model.parameters(), lr=0.01)
loss_fn = nn.BCELoss()

# 训练模型
num_epochs = 10
for epoch in range(num_epochs):
  for user, item, rating in DataLoader(train_set, batch_size=512, shuffle=True):
    # 清空梯度
    optimizer.zero_grad()
    # 前向传播
    predictions = model(user, item)
    # 计算损失
    loss = loss_fn(predictions, rating.float())
    # 反向传播
    loss.backward()
    optimizer.step()
  print(f"Epoch {epoch}, Loss: {loss.item()}")

  # 训练集
  y_pred = np.array([1 if i >= 0.5 else 0 for i in predictions])
  y_true = rating.detach().numpy()
  precision, recall, acc = evaluation(y_pred, y_true)
  print('train: Precision {:.4f} | Recall {:.4f} | accuracy {:.4f}'.format(precision, recall, acc))

  #测试集
  user_test = torch.tensor(test_set)[:,0].detach()
  item_test = torch.tensor(test_set)[:,1].detach()
  predictions = model(user_test, item_test)
  y_pred = np.array([1 if i >= 0.5 else 0 for i in predictions])
  y_true = torch.tensor(test_set)[:,2].detach().float()
  precision, recall, acc = evaluation(y_pred, y_true)
  print('test: Precision {:.4f} | Recall {:.4f} | accuracy {:.4f}'.format(precision, recall, acc))
  print('----------------------------------------------------------------------------------------')
# Out:
# Epoch 0, Loss: 0.7127794623374939
# train: Precision 0.6058 | Recall 0.5806 | accuracy 0.5675
# test: Precision 0.5921 | Recall 0.6297 | accuracy 0.5501
# ----------------------------------------------------------------------------------------
# Epoch 1, Loss: 0.685992419719696
# train: Precision 0.6327 | Recall 0.5536 | accuracy 0.5700
# test: Precision 0.6095 | Recall 0.6166 | accuracy 0.5645
# ----------------------------------------------------------------------------------------
# Epoch 2, Loss: 0.6830658912658691
# train: Precision 0.5724 | Recall 0.7981 | accuracy 0.5750
# test: Precision 0.5939 | Recall 0.7689 | accuracy 0.5765
# ----------------------------------------------------------------------------------------
# Epoch 3, Loss: 0.6747891902923584
# train: Precision 0.5920 | Recall 0.7937 | accuracy 0.5800
# test: Precision 0.5923 | Recall 0.8020 | accuracy 0.5803
# ----------------------------------------------------------------------------------------
# Epoch 4, Loss: 0.672711193561554
# train: Precision 0.6032 | Recall 0.7129 | accuracy 0.6050
# test: Precision 0.6244 | Recall 0.6248 | accuracy 0.5798
# ----------------------------------------------------------------------------------------
# Epoch 5, Loss: 0.652829647064209
# train: Precision 0.6250 | Recall 0.8178 | accuracy 0.6400
# test: Precision 0.6108 | Recall 0.7235 | accuracy 0.5874
# ----------------------------------------------------------------------------------------
# Epoch 6, Loss: 0.671774685382843
# train: Precision 0.5964 | Recall 0.7455 | accuracy 0.5750
# test: Precision 0.6073 | Recall 0.7503 | accuracy 0.5888
# ----------------------------------------------------------------------------------------
# Epoch 7, Loss: 0.6728872656822205
# train: Precision 0.5860 | Recall 0.8326 | accuracy 0.5825
# test: Precision 0.5965 | Recall 0.8071 | accuracy 0.5866
# ----------------------------------------------------------------------------------------
# Epoch 8, Loss: 0.6494268774986267
# train: Precision 0.6875 | Recall 0.7040 | accuracy 0.6150
# test: Precision 0.6164 | Recall 0.7317 | accuracy 0.5951
# ----------------------------------------------------------------------------------------
# Epoch 9, Loss: 0.6555810570716858
# train: Precision 0.6232 | Recall 0.7963 | accuracy 0.6300
# test: Precision 0.6137 | Recall 0.7255 | accuracy 0.5909
# ----------------------------------------------------------------------------------------
